# %% [markdown]
# # Sequence to Sequence (seq2seq) variable length and Attention
#
# The most popular sequence-to-sequence task is translation: usually, from one natural language to another. In the last couple of years, commercial systems became surprisingly good at machine translation - check out, for example, Google Translate, Yandex Translate, DeepL Translator, Bing Microsoft Translator.
#
# More information on the lecture and [here](https://lena-voita.github.io/nlp_course/seq2seq_and_attention.html) (basics+attention part)

# %%
import unicodedata
import re
import numpy as np
import pandas as pd
import os
import io
import time

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
import tensorflow as tf

from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## Data
#
# The data is available here: http://www.manythings.org/anki/. They consist of a set of pairs in the following format:
#
#   `May I borrow this book?`  `¿Puedo tomar prestado este libro?`
#
# There are a variety of languages available, English-Spanish data will be used.
#
# The processing of the data will consist of the following steps:
#
# 1. Removal of special characters
# 1. adding a start or end token to each sentence.
# 1. Creating the vectorizer for each of the two languages

# %%
# Data download
def download_nmt(corpus="spa-eng"):
    path_to_zip = tf.keras.utils.get_file(corpus+".zip",
                                          origin="http://storage.googleapis.com/download.tensorflow.org/data/"+corpus+".zip",
                                          extract=True)
    path_to_file = os.path.dirname(path_to_zip)+"/spa-eng/spa.txt"
    return path_to_file

file_path = download_nmt()
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# 2638744/2638744 [==============================] - 1s 0us/step

# %%
# Process the data
def step1(sent):
    # sent = on sentence in a language
    def unicode_to_ascii(s):
        return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')

    sent = unicode_to_ascii(sent.lower().strip())

    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    sent = re.sub(r"([?.!,¿])", r" \1 ", sent)
    sent = re.sub(r'[" "]+', " ", sent)

    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    sent = re.sub(r"[^a-zA-Z?.!,¿]+", " ", sent)

    return '<start> ' + sent.strip() + ' <end>' # Suppress extra space

# %%
# Loading data
def read_data(path, num_examples, split=0.2):
    # path : path to spa-eng.txt file
    # num_examples : Limit the total number of training example for faster training (set num_examples = len(lines) to use full data)
    lines = io.open(path, encoding='UTF-8').read().strip().split('\n')
    english_sentences, spanish_sentences= zip(*[[step1(sent) for sent in l.split('\t')]  for l in lines[:int((1+split)*num_examples)]])

    return np.array(spanish_sentences), np.array(english_sentences)

num_examples = 700 # of which 100 for testing

spanish_sentences, english_sentences = read_data(file_path, num_examples, split=0.0)
test_spanish_sentences = spanish_sentences[num_examples-100:]
test_english_sentences = english_sentences[num_examples-100:]
spanish_sentences = spanish_sentences[:num_examples-100]
english_sentences = english_sentences[:num_examples-100]
spanish_sentences[100], english_sentences[100]
# Out:
# ('<start> salga de aqui ! <end>', '<start> go away ! <end>')

# %%
# Search vocabulary and max_length for each language
def voc(lang):
    # a list of sentences in the same language
    lengths = [len(txt.split()) for txt in lang]
    vocab = set([w for txt in lang for w in txt.split()])  

    return max(lengths), list(vocab), len(vocab)+2 # for padding and OOV

max_length_spanish, vocab_spanish, vocab_size_spanish = voc(spanish_sentences)
max_length_english, vocab_english, vocab_size_english = voc(english_sentences)

# %%
pd.DataFrame({"lang":["english", "spanish"],
              "max_length":[max_length_english, max_length_spanish],
              "vocab_size": [vocab_size_english, vocab_size_spanish]}).head()
# Out:
#       lang  max_length  vocab_size
# 0  english           7         279
# 1  spanish           8         548

# %%
# Build vectorizer layer
english_vectorizer = layers.TextVectorization(standardize=None, output_mode='int',
                                              vocabulary=vocab_english,
                                              name="English_vect")
# On peut connaitre le vocabulaire par english_vectorizer.get_vocabulary()

# Do the same for spanish
spanish_vectorizer = layers.TextVectorization(standardize=None, output_mode='int',
                                              vocabulary=vocab_spanish,
                                              name="Spanish_vect")

# %%
BATCH_SIZE = 32
embedding_dim = 50
latent_dim = 64
dropout=0.3

# %% [markdown]
# ## Training model

# %%
attention_func = 'MLP' # others possibility: 'dot', 'bilinear', 'MLP'

# %%
""" Encoder part """
encoder_inputs = layers.Input(shape=(1,), dtype=tf.string, name="spanish")
encoder_vectorizer = spanish_vectorizer(encoder_inputs) #transform sentence in tokens (output=length)
encoder_embedding = layers.Embedding(vocab_size_spanish, embedding_dim, #embedd each token
                                     name="spanish_embedding")(encoder_vectorizer)
encoder_outputs, encoder_state_h, encoder_state_c = layers.LSTM(latent_dim, return_sequences=True, return_state=True,
                           dropout=dropout, recurrent_dropout=dropout, name="encoder")(encoder_embedding)

# We discard `encoder_outputs` and only keep the states. 
encoder_states = [encoder_state_h, encoder_state_c]

print(encoder_outputs.shape)
# Out:
# (None, None, 64)

# %%
""" Decoder part """
# Set up the decoder, using `encoder_states` as initial state. 
decoder_inputs = layers.Input(shape=(None,), dtype=tf.int32, name="english_teacher")
decoder_embedding = layers.Embedding(vocab_size_english, embedding_dim,
                                     name="english_embedding")(decoder_inputs)
decoder_outputs, decoder_state_h, decoder_state_c = layers.LSTM(latent_dim, return_sequences=True, return_state=True,
                                                                dropout=dropout, recurrent_dropout=dropout, name="Decoder")(decoder_embedding, initial_state=encoder_states)

print(decoder_outputs.shape)
# Out:
# (None, None, 64)

# %% [markdown]
#  ![General computation scheme](https://lena-voita.github.io/resources/lectures/seq2seq/attention/computation_scheme-min.png)

# %%
""" Attentional part """
# We use all encoder ouput

if attention_func=='dot':
    # Scoring funtion Dot
    print("dot")
    attention = layers.dot([decoder_outputs, encoder_outputs], axes=[2,2], name="Attention_score")
elif attention_func=='bilinear':
    # Scoring function Bilinear
    print("bilinear")
    attention = layers.Dense(latent_dim, activation="linear", name="dense_bilinear")(encoder_outputs)
    attention = layers.dot([decoder_outputs, attention], axes=[2,2], name="Attention_score")
elif attention_func=="MLP": #Here we use this one cuz we stick to MLP
    # Scoring function MLP - need to know encoder_max_len / decoder_max_len
    print("MLP")
    attention_encoder = layers.Dense(latent_dim, activation="tanh", name="dense_encoder")(encoder_outputs)
    attention_decoder = layers.Dense(latent_dim, activation="tanh", name="dense_decoder")(decoder_outputs)
    attention = layers.dot([attention_decoder, attention_encoder], axes=[2,2], name="Attention_score")

if attention_func is not None:
    attention = layers.Activation('softmax', name="Attention_weight")(attention)
    print(attention.shape)
# Out:
# MLP
# (None, None, None)

# %%
""" Context vector """
if attention_func is not None:
    context = layers.dot([attention, encoder_outputs], axes=[2,1], name="Attention_output")
    print(context.shape)
# Out:
# (None, None, 64)

# %%
""" Combine attention with decoder ouput """
if attention_func is None:
    print("without attention")
    decoder_combined_context = decoder_outputs
else:
    print("with attention")
    decoder_combined_context = layers.concatenate([context, decoder_outputs], name="Luong_Attention")
print(decoder_combined_context.shape)
# Out:
# with attention
# (None, None, 128)

# %%
""" Ouput of the model """
ouputs = layers.Dense(vocab_size_english, activation='softmax', name="Output")(decoder_combined_context)
print(decoder_outputs.shape)
# Out:
# (None, None, 64)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  spanish (InputLayer)           [(None, 1)]          0           []
#
#  Spanish_vect (TextVectorizatio  (None, None)        0           ['spanish[0][0]']
#  n)
#
#  english_teacher (InputLayer)   [(None, None)]       0           []
#
#  spanish_embedding (Embedding)  (None, None, 50)     27400       ['Spanish_vect[0][0]']
#
#  snglish_embedding (Embedding)  (None, None, 50)     13950       ['english_teacher[0][0]']
#
#  encoder (LSTM)                 [(None, None, 64),   29440       ['spanish_embedding[0][0]']
#                                  (None, 64),
#                                  (None, 64)]
#
#  Decoder (LSTM)                 [(None, None, 64),   29440       ['snglish_embedding[0][0]',
#                                  (None, 64),                      'encoder[0][1]',
#                                  (None, 64)]                      'encoder[0][2]']
#
#  dense_decoder (Dense)          (None, None, 64)     4160        ['Decoder[0][0]']
#
#  dense_encoder (Dense)          (None, None, 64)     4160        ['encoder[0][0]']
#
#  Attention_score (Dot)          (None, None, None)   0           ['dense_decoder[0][0]',
#                                                                   'dense_encoder[0][0]']
#
#  Attention_weight (Activation)  (None, None, None)   0           ['Attention_score[0][0]']
#
#  Attention_output (Dot)         (None, None, 64)     0           ['Attention_weight[0][0]',
#                                                                   'encoder[0][0]']
#
#  Luong_Attention (Concatenate)  (None, None, 128)    0           ['Attention_output[0][0]',
#                                                                   'Decoder[0][0]']
#
#  Output (Dense)                 (None, None, 279)    35991       ['Luong_Attention[0][0]']
#
# ==================================================================================================
# Total params: 144,541
# Trainable params: 144,541
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
""" The model """
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], ouputs)

plot_model(model, show_shapes=True)

# %%
# Prepare training data with teacher forcing
# decoder_input_data is a 2D array of shape (None, None) containing a tokenization of the English sentences.
# decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t] will be the same as decoder_input_data[:, t-1].

english_teacher_enc = english_vectorizer(english_sentences).numpy() # Teacher
english_target_enc = np.zeros_like(english_teacher_enc)
english_target_enc[:,:-1] = english_teacher_enc[:,1:] # To predict
english_target_enc.shape
# Out:
# (600, 7)

# %%
#model.compile(loss='sparse_categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# <font color=red>
# We voluntarily choose to stop on loss in order to have overfitting: too little data to train (or too long training time if we take more data).
#
# Obviously in real life... this is not something to do.
#
# Nevertheless, we keep a validation set to see the overtraining
# </font>

# %%
# Configure the model and start training
# Stop training with early stopping with patience of 20
callbacks_list = [EarlyStopping(monitor='loss', mode='min', min_delta=0.000001,
                                patience=5, restore_best_weights=True, verbose=1,
                                )]
history = model.fit([spanish_sentences, english_teacher_enc], english_target_enc,
                    validation_split=0.1,
                    epochs=1000, batch_size=BATCH_SIZE,
                    callbacks=callbacks_list,
                    verbose=1)
# Out:
# Epoch 1/1000
# 17/17 [==============================] - 10s 80ms/step - loss: 4.2919 - accuracy: 0.3796 - val_loss: 2.9337 - val_accuracy: 0.2857
# Epoch 2/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 2.4060 - accuracy: 0.4130 - val_loss: 2.8509 - val_accuracy: 0.2857
# Epoch 3/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 2.2510 - accuracy: 0.4630 - val_loss: 2.9965 - val_accuracy: 0.3286
# Epoch 4/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 2.1325 - accuracy: 0.5286 - val_loss: 2.9684 - val_accuracy: 0.4190
# Epoch 5/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 2.0548 - accuracy: 0.5471 - val_loss: 2.9237 - val_accuracy: 0.4381
# Epoch 6/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 1.9562 - accuracy: 0.5841 - val_loss: 2.4028 - val_accuracy: 0.6738
# Epoch 7/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 1.9202 - accuracy: 0.6111 - val_loss: 2.9026 - val_accuracy: 0.4381
# Epoch 8/1000
# 17/17 [==============================] - 1s 37ms/step - loss: 1.8515 - accuracy: 0.6413 - val_loss: 2.3279 - val_accuracy: 0.7048
# Epoch 9/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 1.8053 - accuracy: 0.6558 - val_loss: 2.3586 - val_accuracy: 0.6833
# Epoch 10/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 1.7456 - accuracy: 0.6772 - val_loss: 2.3011 - val_accuracy: 0.7095
# Epoch 11/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 1.6872 - accuracy: 0.6844 - val_loss: 2.2366 - val_accuracy: 0.7095
# Epoch 12/1000
# 17/17 [==============================] - 1s 29ms/step - loss: 1.6575 - accuracy: 0.6844 - val_loss: 2.2582 - val_accuracy: 0.7095
# Epoch 13/1000
# 17/17 [==============================] - 1s 33ms/step - loss: 1.6009 - accuracy: 0.6884 - val_loss: 2.3499 - val_accuracy: 0.7095
# Epoch 14/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 1.5685 - accuracy: 0.6905 - val_loss: 2.2772 - val_accuracy: 0.7452
# Epoch 15/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 1.5429 - accuracy: 0.6913 - val_loss: 2.2560 - val_accuracy: 0.7548
# Epoch 16/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 1.5212 - accuracy: 0.6947 - val_loss: 2.2842 - val_accuracy: 0.7548
# Epoch 17/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 1.4984 - accuracy: 0.6974 - val_loss: 2.2190 - val_accuracy: 0.7548
# Epoch 18/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 1.4723 - accuracy: 0.7005 - val_loss: 2.2754 - val_accuracy: 0.7548
# Epoch 19/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 1.4468 - accuracy: 0.7050 - val_loss: 2.2927 - val_accuracy: 0.7548
# Epoch 20/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 1.4318 - accuracy: 0.7111 - val_loss: 2.2680 - val_accuracy: 0.7548
# Epoch 21/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 1.3973 - accuracy: 0.7175 - val_loss: 2.2252 - val_accuracy: 0.7548
# Epoch 22/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 1.3866 - accuracy: 0.7167 - val_loss: 2.3685 - val_accuracy: 0.7524
# Epoch 23/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 1.3622 - accuracy: 0.7233 - val_loss: 2.2716 - val_accuracy: 0.7548
# Epoch 24/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 1.3370 - accuracy: 0.7233 - val_loss: 2.3196 - val_accuracy: 0.7500
# Epoch 25/1000
# 17/17 [==============================] - 1s 29ms/step - loss: 1.3135 - accuracy: 0.7275 - val_loss: 2.1928 - val_accuracy: 0.7524
# Epoch 26/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 1.2936 - accuracy: 0.7302 - val_loss: 2.1775 - val_accuracy: 0.7405
# Epoch 27/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 1.2782 - accuracy: 0.7339 - val_loss: 2.2112 - val_accuracy: 0.7524
# Epoch 28/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 1.2574 - accuracy: 0.7362 - val_loss: 2.1668 - val_accuracy: 0.7429
# Epoch 29/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 1.2369 - accuracy: 0.7397 - val_loss: 2.1578 - val_accuracy: 0.7476
# Epoch 30/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 1.2264 - accuracy: 0.7421 - val_loss: 2.1544 - val_accuracy: 0.7333
# Epoch 31/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 1.2064 - accuracy: 0.7444 - val_loss: 2.2589 - val_accuracy: 0.7238
# Epoch 32/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 1.1870 - accuracy: 0.7466 - val_loss: 2.1536 - val_accuracy: 0.7310
# Epoch 33/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 1.1766 - accuracy: 0.7519 - val_loss: 2.1570 - val_accuracy: 0.7333
# Epoch 34/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 1.1628 - accuracy: 0.7503 - val_loss: 2.2078 - val_accuracy: 0.7238
# Epoch 35/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 1.1476 - accuracy: 0.7587 - val_loss: 2.2859 - val_accuracy: 0.7119
# Epoch 36/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 1.1308 - accuracy: 0.7606 - val_loss: 2.1564 - val_accuracy: 0.7310
# Epoch 37/1000
# 17/17 [==============================] - 1s 39ms/step - loss: 1.1143 - accuracy: 0.7611 - val_loss: 2.1774 - val_accuracy: 0.7262
# Epoch 38/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 1.0968 - accuracy: 0.7646 - val_loss: 2.1906 - val_accuracy: 0.7262
# Epoch 39/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 1.0826 - accuracy: 0.7680 - val_loss: 2.2629 - val_accuracy: 0.7310
# Epoch 40/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 1.0718 - accuracy: 0.7690 - val_loss: 2.2360 - val_accuracy: 0.7262
# Epoch 41/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 1.0504 - accuracy: 0.7712 - val_loss: 2.2175 - val_accuracy: 0.7286
# Epoch 42/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 1.0384 - accuracy: 0.7728 - val_loss: 2.2372 - val_accuracy: 0.7262
# Epoch 43/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 1.0194 - accuracy: 0.7765 - val_loss: 2.3577 - val_accuracy: 0.7214
# Epoch 44/1000
# 17/17 [==============================] - 1s 56ms/step - loss: 1.0040 - accuracy: 0.7775 - val_loss: 2.2532 - val_accuracy: 0.7262
# Epoch 45/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.9867 - accuracy: 0.7823 - val_loss: 2.3248 - val_accuracy: 0.7119
# Epoch 46/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9725 - accuracy: 0.7815 - val_loss: 2.3559 - val_accuracy: 0.7214
# Epoch 47/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9621 - accuracy: 0.7841 - val_loss: 2.3718 - val_accuracy: 0.7119
# Epoch 48/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.9479 - accuracy: 0.7852 - val_loss: 2.3012 - val_accuracy: 0.7238
# Epoch 49/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 0.9346 - accuracy: 0.7860 - val_loss: 2.3354 - val_accuracy: 0.7119
# Epoch 50/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 0.9173 - accuracy: 0.7907 - val_loss: 2.2982 - val_accuracy: 0.7238
# Epoch 51/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.9092 - accuracy: 0.7918 - val_loss: 2.3556 - val_accuracy: 0.7262
# Epoch 52/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.8972 - accuracy: 0.7942 - val_loss: 2.3616 - val_accuracy: 0.7262
# Epoch 53/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.8867 - accuracy: 0.7958 - val_loss: 2.4196 - val_accuracy: 0.7119
# Epoch 54/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.8689 - accuracy: 0.7987 - val_loss: 2.3654 - val_accuracy: 0.7262
# Epoch 55/1000
# 17/17 [==============================] - 1s 29ms/step - loss: 0.8571 - accuracy: 0.8013 - val_loss: 2.3941 - val_accuracy: 0.7167
# Epoch 56/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.8495 - accuracy: 0.7997 - val_loss: 2.4333 - val_accuracy: 0.7167
# Epoch 57/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.8365 - accuracy: 0.8026 - val_loss: 2.4202 - val_accuracy: 0.7262
# Epoch 58/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.8226 - accuracy: 0.8050 - val_loss: 2.4088 - val_accuracy: 0.7238
# Epoch 59/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.8161 - accuracy: 0.8069 - val_loss: 2.4609 - val_accuracy: 0.7095
# Epoch 60/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.8033 - accuracy: 0.8071 - val_loss: 2.4332 - val_accuracy: 0.7167
# Epoch 61/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.7904 - accuracy: 0.8127 - val_loss: 2.4450 - val_accuracy: 0.7167
# Epoch 62/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.7815 - accuracy: 0.8119 - val_loss: 2.4288 - val_accuracy: 0.7214
# Epoch 63/1000
# 17/17 [==============================] - 1s 36ms/step - loss: 0.7694 - accuracy: 0.8172 - val_loss: 2.4672 - val_accuracy: 0.7143
# Epoch 64/1000
# 17/17 [==============================] - 1s 36ms/step - loss: 0.7576 - accuracy: 0.8196 - val_loss: 2.4580 - val_accuracy: 0.7214
# Epoch 65/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.7518 - accuracy: 0.8185 - val_loss: 2.4839 - val_accuracy: 0.7143
# Epoch 66/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.7383 - accuracy: 0.8222 - val_loss: 2.4911 - val_accuracy: 0.7167
# Epoch 67/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.7284 - accuracy: 0.8217 - val_loss: 2.5153 - val_accuracy: 0.7095
# Epoch 68/1000
# 17/17 [==============================] - 1s 74ms/step - loss: 0.7220 - accuracy: 0.8259 - val_loss: 2.5156 - val_accuracy: 0.7143
# Epoch 69/1000
# 17/17 [==============================] - 1s 69ms/step - loss: 0.7086 - accuracy: 0.8272 - val_loss: 2.5038 - val_accuracy: 0.7143
# Epoch 70/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.7035 - accuracy: 0.8283 - val_loss: 2.5178 - val_accuracy: 0.7119
# Epoch 71/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.6942 - accuracy: 0.8312 - val_loss: 2.5403 - val_accuracy: 0.7167
# Epoch 72/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.6841 - accuracy: 0.8299 - val_loss: 2.5883 - val_accuracy: 0.7000
# Epoch 73/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.6755 - accuracy: 0.8323 - val_loss: 2.5775 - val_accuracy: 0.7048
# Epoch 74/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.6646 - accuracy: 0.8328 - val_loss: 2.5639 - val_accuracy: 0.7048
# Epoch 75/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.6618 - accuracy: 0.8373 - val_loss: 2.5694 - val_accuracy: 0.7048
# Epoch 76/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.6499 - accuracy: 0.8407 - val_loss: 2.6012 - val_accuracy: 0.7119
# Epoch 77/1000
# 17/17 [==============================] - 1s 36ms/step - loss: 0.6419 - accuracy: 0.8413 - val_loss: 2.5676 - val_accuracy: 0.7095
# Epoch 78/1000
# 17/17 [==============================] - 1s 37ms/step - loss: 0.6398 - accuracy: 0.8418 - val_loss: 2.5890 - val_accuracy: 0.7071
# Epoch 79/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.6313 - accuracy: 0.8447 - val_loss: 2.5928 - val_accuracy: 0.7071
# Epoch 80/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.6210 - accuracy: 0.8466 - val_loss: 2.6235 - val_accuracy: 0.6952
# Epoch 81/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.6162 - accuracy: 0.8458 - val_loss: 2.6304 - val_accuracy: 0.7048
# Epoch 82/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.6092 - accuracy: 0.8497 - val_loss: 2.6042 - val_accuracy: 0.7071
# Epoch 83/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.5997 - accuracy: 0.8492 - val_loss: 2.6558 - val_accuracy: 0.7000
# Epoch 84/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.5951 - accuracy: 0.8508 - val_loss: 2.6278 - val_accuracy: 0.7095
# Epoch 85/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.5872 - accuracy: 0.8532 - val_loss: 2.6250 - val_accuracy: 0.7095
# Epoch 86/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.5808 - accuracy: 0.8563 - val_loss: 2.6475 - val_accuracy: 0.6952
# Epoch 87/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.5730 - accuracy: 0.8550 - val_loss: 2.6593 - val_accuracy: 0.7000
# Epoch 88/1000
# 17/17 [==============================] - 1s 61ms/step - loss: 0.5644 - accuracy: 0.8587 - val_loss: 2.6745 - val_accuracy: 0.6952
# Epoch 89/1000
# 17/17 [==============================] - 1s 52ms/step - loss: 0.5627 - accuracy: 0.8556 - val_loss: 2.6931 - val_accuracy: 0.6619
# Epoch 90/1000
# 17/17 [==============================] - 1s 53ms/step - loss: 0.5583 - accuracy: 0.8614 - val_loss: 2.6366 - val_accuracy: 0.7000
# Epoch 91/1000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5485 - accuracy: 0.8598 - val_loss: 2.7618 - val_accuracy: 0.6857
# Epoch 92/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.5444 - accuracy: 0.8593 - val_loss: 2.6471 - val_accuracy: 0.7024
# Epoch 93/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.5451 - accuracy: 0.8574 - val_loss: 2.6752 - val_accuracy: 0.6976
# Epoch 94/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.5337 - accuracy: 0.8638 - val_loss: 2.6737 - val_accuracy: 0.6929
# Epoch 95/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.5307 - accuracy: 0.8638 - val_loss: 2.6733 - val_accuracy: 0.7000
# Epoch 96/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.5219 - accuracy: 0.8608 - val_loss: 2.6981 - val_accuracy: 0.6952
# Epoch 97/1000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5206 - accuracy: 0.8680 - val_loss: 2.7086 - val_accuracy: 0.6976
# Epoch 98/1000
# 17/17 [==============================] - 1s 68ms/step - loss: 0.5156 - accuracy: 0.8648 - val_loss: 2.6862 - val_accuracy: 0.7000
# Epoch 99/1000
# 17/17 [==============================] - 1s 71ms/step - loss: 0.4995 - accuracy: 0.8720 - val_loss: 2.7470 - val_accuracy: 0.6952
# Epoch 100/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.5023 - accuracy: 0.8704 - val_loss: 2.7056 - val_accuracy: 0.6976
# Epoch 101/1000
# 17/17 [==============================] - 1s 36ms/step - loss: 0.4965 - accuracy: 0.8667 - val_loss: 2.7004 - val_accuracy: 0.7071
# Epoch 102/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.4958 - accuracy: 0.8725 - val_loss: 2.7142 - val_accuracy: 0.7024
# Epoch 103/1000
# 17/17 [==============================] - 1s 52ms/step - loss: 0.4882 - accuracy: 0.8688 - val_loss: 2.7516 - val_accuracy: 0.6905
# Epoch 104/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.4790 - accuracy: 0.8786 - val_loss: 2.8344 - val_accuracy: 0.6833
# Epoch 105/1000
# 17/17 [==============================] - 1s 56ms/step - loss: 0.4832 - accuracy: 0.8693 - val_loss: 2.6919 - val_accuracy: 0.7143
# Epoch 106/1000
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4717 - accuracy: 0.8728 - val_loss: 2.7650 - val_accuracy: 0.7000
# Epoch 107/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.4683 - accuracy: 0.8738 - val_loss: 2.6996 - val_accuracy: 0.7143
# Epoch 108/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.4655 - accuracy: 0.8754 - val_loss: 2.7024 - val_accuracy: 0.7143
# Epoch 109/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.4583 - accuracy: 0.8757 - val_loss: 2.7238 - val_accuracy: 0.7143
# Epoch 110/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.4604 - accuracy: 0.8786 - val_loss: 2.6965 - val_accuracy: 0.7190
# Epoch 111/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.4501 - accuracy: 0.8775 - val_loss: 2.6674 - val_accuracy: 0.7143
# Epoch 112/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.4475 - accuracy: 0.8791 - val_loss: 2.7144 - val_accuracy: 0.7214
# Epoch 113/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.4474 - accuracy: 0.8802 - val_loss: 2.7517 - val_accuracy: 0.7119
# Epoch 114/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.4396 - accuracy: 0.8836 - val_loss: 2.7361 - val_accuracy: 0.7214
# Epoch 115/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.4385 - accuracy: 0.8807 - val_loss: 2.8201 - val_accuracy: 0.7000
# Epoch 116/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.4307 - accuracy: 0.8836 - val_loss: 2.8882 - val_accuracy: 0.7024
# Epoch 117/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.4308 - accuracy: 0.8831 - val_loss: 2.8067 - val_accuracy: 0.7000
# Epoch 118/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.4237 - accuracy: 0.8849 - val_loss: 2.7688 - val_accuracy: 0.7119
# Epoch 119/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.4196 - accuracy: 0.8889 - val_loss: 2.7966 - val_accuracy: 0.7143
# Epoch 120/1000
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4169 - accuracy: 0.8905 - val_loss: 2.7868 - val_accuracy: 0.7143
# Epoch 121/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.4082 - accuracy: 0.8892 - val_loss: 2.8607 - val_accuracy: 0.6976
# Epoch 122/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.4101 - accuracy: 0.8905 - val_loss: 2.8192 - val_accuracy: 0.7000
# Epoch 123/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.4056 - accuracy: 0.8902 - val_loss: 2.7749 - val_accuracy: 0.7143
# Epoch 124/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.4018 - accuracy: 0.8923 - val_loss: 2.7870 - val_accuracy: 0.7119
# Epoch 125/1000
# 17/17 [==============================] - 1s 55ms/step - loss: 0.3984 - accuracy: 0.8929 - val_loss: 2.8534 - val_accuracy: 0.7024
# Epoch 126/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.3923 - accuracy: 0.9000 - val_loss: 2.7826 - val_accuracy: 0.7190
# Epoch 127/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 0.3867 - accuracy: 0.8971 - val_loss: 2.7714 - val_accuracy: 0.7119
# Epoch 128/1000
# 17/17 [==============================] - 1s 29ms/step - loss: 0.3886 - accuracy: 0.8952 - val_loss: 2.8091 - val_accuracy: 0.7190
# Epoch 129/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.3869 - accuracy: 0.8989 - val_loss: 2.8061 - val_accuracy: 0.7190
# Epoch 130/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 0.3798 - accuracy: 0.8966 - val_loss: 2.8662 - val_accuracy: 0.7095
# Epoch 131/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.3774 - accuracy: 0.8987 - val_loss: 2.8240 - val_accuracy: 0.7095
# Epoch 132/1000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.3766 - accuracy: 0.8989 - val_loss: 2.8920 - val_accuracy: 0.6857
# Epoch 133/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.3726 - accuracy: 0.9005 - val_loss: 2.7851 - val_accuracy: 0.7143
# Epoch 134/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.3712 - accuracy: 0.8981 - val_loss: 2.8509 - val_accuracy: 0.7095
# Epoch 135/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.3611 - accuracy: 0.9024 - val_loss: 2.8572 - val_accuracy: 0.7095
# Epoch 136/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.3662 - accuracy: 0.8987 - val_loss: 2.7694 - val_accuracy: 0.7214
# Epoch 137/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.3666 - accuracy: 0.9013 - val_loss: 2.8916 - val_accuracy: 0.7000
# Epoch 138/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.3580 - accuracy: 0.9053 - val_loss: 2.7916 - val_accuracy: 0.7143
# Epoch 139/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.3585 - accuracy: 0.9016 - val_loss: 2.8274 - val_accuracy: 0.7071
# Epoch 140/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.3545 - accuracy: 0.9050 - val_loss: 2.9276 - val_accuracy: 0.7024
# Epoch 141/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.3514 - accuracy: 0.9034 - val_loss: 2.8532 - val_accuracy: 0.7048
# Epoch 142/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.3497 - accuracy: 0.9045 - val_loss: 2.8771 - val_accuracy: 0.6905
# Epoch 143/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.3373 - accuracy: 0.9093 - val_loss: 2.8106 - val_accuracy: 0.7190
# Epoch 144/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.3386 - accuracy: 0.9085 - val_loss: 2.8475 - val_accuracy: 0.7167
# Epoch 145/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.3327 - accuracy: 0.9146 - val_loss: 2.8577 - val_accuracy: 0.7119
# Epoch 146/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.3323 - accuracy: 0.9114 - val_loss: 2.8909 - val_accuracy: 0.7095
# Epoch 147/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.3296 - accuracy: 0.9090 - val_loss: 2.8901 - val_accuracy: 0.7024
# Epoch 148/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.3282 - accuracy: 0.9103 - val_loss: 2.7822 - val_accuracy: 0.7262
# Epoch 149/1000
# 17/17 [==============================] - 1s 36ms/step - loss: 0.3240 - accuracy: 0.9127 - val_loss: 2.7574 - val_accuracy: 0.7286
# Epoch 150/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.3273 - accuracy: 0.9093 - val_loss: 2.8097 - val_accuracy: 0.7143
# Epoch 151/1000
# 17/17 [==============================] - 1s 29ms/step - loss: 0.3165 - accuracy: 0.9153 - val_loss: 3.0346 - val_accuracy: 0.6833
# Epoch 152/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.3177 - accuracy: 0.9140 - val_loss: 2.7573 - val_accuracy: 0.7214
# Epoch 153/1000
# 17/17 [==============================] - 1s 39ms/step - loss: 0.3129 - accuracy: 0.9138 - val_loss: 2.7854 - val_accuracy: 0.7262
# Epoch 154/1000
# 17/17 [==============================] - 1s 52ms/step - loss: 0.3147 - accuracy: 0.9156 - val_loss: 2.9218 - val_accuracy: 0.6857
# Epoch 155/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.3152 - accuracy: 0.9180 - val_loss: 2.7932 - val_accuracy: 0.7143
# Epoch 156/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.3155 - accuracy: 0.9159 - val_loss: 2.8354 - val_accuracy: 0.6952
# Epoch 157/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.3060 - accuracy: 0.9156 - val_loss: 2.8207 - val_accuracy: 0.6976
# Epoch 158/1000
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2969 - accuracy: 0.9222 - val_loss: 2.8929 - val_accuracy: 0.7000
# Epoch 159/1000
# 17/17 [==============================] - 1s 53ms/step - loss: 0.2952 - accuracy: 0.9230 - val_loss: 2.8270 - val_accuracy: 0.7143
# Epoch 160/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 0.2976 - accuracy: 0.9206 - val_loss: 2.7710 - val_accuracy: 0.7286
# Epoch 161/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.2985 - accuracy: 0.9185 - val_loss: 2.8290 - val_accuracy: 0.7143
# Epoch 162/1000
# 17/17 [==============================] - 1s 29ms/step - loss: 0.2936 - accuracy: 0.9225 - val_loss: 2.8111 - val_accuracy: 0.7071
# Epoch 163/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.2934 - accuracy: 0.9220 - val_loss: 2.8718 - val_accuracy: 0.6929
# Epoch 164/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.2892 - accuracy: 0.9198 - val_loss: 2.8111 - val_accuracy: 0.7071
# Epoch 165/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.2878 - accuracy: 0.9228 - val_loss: 2.8074 - val_accuracy: 0.7024
# Epoch 166/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.2920 - accuracy: 0.9193 - val_loss: 2.8724 - val_accuracy: 0.7095
# Epoch 167/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.2850 - accuracy: 0.9251 - val_loss: 2.7869 - val_accuracy: 0.7238
# Epoch 168/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.2790 - accuracy: 0.9233 - val_loss: 2.8664 - val_accuracy: 0.6976
# Epoch 169/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.2726 - accuracy: 0.9267 - val_loss: 2.8099 - val_accuracy: 0.7214
# Epoch 170/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.2760 - accuracy: 0.9267 - val_loss: 2.8192 - val_accuracy: 0.7238
# Epoch 171/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2695 - accuracy: 0.9275 - val_loss: 2.8714 - val_accuracy: 0.7119
# Epoch 172/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.2663 - accuracy: 0.9286 - val_loss: 2.8252 - val_accuracy: 0.7167
# Epoch 173/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2654 - accuracy: 0.9270 - val_loss: 2.8015 - val_accuracy: 0.7167
# Epoch 174/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2712 - accuracy: 0.9278 - val_loss: 2.7860 - val_accuracy: 0.7190
# Epoch 175/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2595 - accuracy: 0.9307 - val_loss: 2.9374 - val_accuracy: 0.6905
# Epoch 176/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2606 - accuracy: 0.9296 - val_loss: 2.8294 - val_accuracy: 0.6976
# Epoch 177/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2593 - accuracy: 0.9320 - val_loss: 2.8172 - val_accuracy: 0.7071
# Epoch 178/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2519 - accuracy: 0.9312 - val_loss: 2.8794 - val_accuracy: 0.6905
# Epoch 179/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2515 - accuracy: 0.9315 - val_loss: 2.8630 - val_accuracy: 0.6929
# Epoch 180/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2463 - accuracy: 0.9325 - val_loss: 2.8184 - val_accuracy: 0.7238
# Epoch 181/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.2454 - accuracy: 0.9320 - val_loss: 2.8976 - val_accuracy: 0.6976
# Epoch 182/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2459 - accuracy: 0.9323 - val_loss: 2.8370 - val_accuracy: 0.7167
# Epoch 183/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2446 - accuracy: 0.9347 - val_loss: 2.8564 - val_accuracy: 0.7048
# Epoch 184/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.2474 - accuracy: 0.9328 - val_loss: 2.8144 - val_accuracy: 0.7262
# Epoch 185/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2407 - accuracy: 0.9368 - val_loss: 2.7712 - val_accuracy: 0.7310
# Epoch 186/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2359 - accuracy: 0.9352 - val_loss: 2.8691 - val_accuracy: 0.6952
# Epoch 187/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.2311 - accuracy: 0.9397 - val_loss: 2.8003 - val_accuracy: 0.7262
# Epoch 188/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.2410 - accuracy: 0.9331 - val_loss: 2.8686 - val_accuracy: 0.7190
# Epoch 189/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.2359 - accuracy: 0.9370 - val_loss: 2.8446 - val_accuracy: 0.6976
# Epoch 190/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.2339 - accuracy: 0.9378 - val_loss: 2.8510 - val_accuracy: 0.7024
# Epoch 191/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.2276 - accuracy: 0.9373 - val_loss: 2.9165 - val_accuracy: 0.6905
# Epoch 192/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.2315 - accuracy: 0.9378 - val_loss: 2.8154 - val_accuracy: 0.7167
# Epoch 193/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.2289 - accuracy: 0.9392 - val_loss: 2.8214 - val_accuracy: 0.7119
# Epoch 194/1000
# 17/17 [==============================] - 1s 38ms/step - loss: 0.2279 - accuracy: 0.9378 - val_loss: 2.8207 - val_accuracy: 0.7286
# Epoch 195/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.2197 - accuracy: 0.9392 - val_loss: 2.7958 - val_accuracy: 0.7238
# Epoch 196/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.2144 - accuracy: 0.9410 - val_loss: 2.8041 - val_accuracy: 0.7238
# Epoch 197/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.2145 - accuracy: 0.9415 - val_loss: 2.8356 - val_accuracy: 0.7214
# Epoch 198/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.2153 - accuracy: 0.9426 - val_loss: 2.8467 - val_accuracy: 0.7167
# Epoch 199/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.2113 - accuracy: 0.9439 - val_loss: 2.8669 - val_accuracy: 0.6952
# Epoch 200/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.2148 - accuracy: 0.9405 - val_loss: 2.8177 - val_accuracy: 0.7238
# Epoch 201/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.2136 - accuracy: 0.9413 - val_loss: 2.8294 - val_accuracy: 0.7071
# Epoch 202/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.2075 - accuracy: 0.9426 - val_loss: 2.8440 - val_accuracy: 0.6929
# Epoch 203/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.2069 - accuracy: 0.9402 - val_loss: 2.7978 - val_accuracy: 0.7143
# Epoch 204/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.2063 - accuracy: 0.9426 - val_loss: 2.8562 - val_accuracy: 0.6952
# Epoch 205/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.1992 - accuracy: 0.9455 - val_loss: 2.7891 - val_accuracy: 0.7214
# Epoch 206/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.2073 - accuracy: 0.9376 - val_loss: 2.8651 - val_accuracy: 0.6929
# Epoch 207/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2011 - accuracy: 0.9439 - val_loss: 2.8454 - val_accuracy: 0.7048
# Epoch 208/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.2058 - accuracy: 0.9423 - val_loss: 2.8138 - val_accuracy: 0.7167
# Epoch 209/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1969 - accuracy: 0.9442 - val_loss: 2.7688 - val_accuracy: 0.7214
# Epoch 210/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.2016 - accuracy: 0.9431 - val_loss: 2.8619 - val_accuracy: 0.6952
# Epoch 211/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.1974 - accuracy: 0.9439 - val_loss: 2.8371 - val_accuracy: 0.6952
# Epoch 212/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1915 - accuracy: 0.9450 - val_loss: 2.8527 - val_accuracy: 0.6905
# Epoch 213/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1916 - accuracy: 0.9466 - val_loss: 2.8629 - val_accuracy: 0.6929
# Epoch 214/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1893 - accuracy: 0.9479 - val_loss: 2.7812 - val_accuracy: 0.7214
# Epoch 215/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1885 - accuracy: 0.9450 - val_loss: 2.9217 - val_accuracy: 0.6810
# Epoch 216/1000
# 17/17 [==============================] - 1s 29ms/step - loss: 0.1879 - accuracy: 0.9489 - val_loss: 2.8729 - val_accuracy: 0.6952
# Epoch 217/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1858 - accuracy: 0.9492 - val_loss: 2.7754 - val_accuracy: 0.7238
# Epoch 218/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.1820 - accuracy: 0.9516 - val_loss: 2.8366 - val_accuracy: 0.6905
# Epoch 219/1000
# 17/17 [==============================] - 1s 30ms/step - loss: 0.1833 - accuracy: 0.9471 - val_loss: 2.8080 - val_accuracy: 0.7071
# Epoch 220/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1798 - accuracy: 0.9489 - val_loss: 2.8044 - val_accuracy: 0.7143
# Epoch 221/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1783 - accuracy: 0.9545 - val_loss: 2.9378 - val_accuracy: 0.6833
# Epoch 222/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.1810 - accuracy: 0.9503 - val_loss: 2.8207 - val_accuracy: 0.7071
# Epoch 223/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1803 - accuracy: 0.9513 - val_loss: 2.8212 - val_accuracy: 0.7024
# Epoch 224/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1786 - accuracy: 0.9516 - val_loss: 2.8526 - val_accuracy: 0.7143
# Epoch 225/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.1742 - accuracy: 0.9500 - val_loss: 2.9398 - val_accuracy: 0.6905
# Epoch 226/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1745 - accuracy: 0.9516 - val_loss: 2.8147 - val_accuracy: 0.7119
# Epoch 227/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1748 - accuracy: 0.9529 - val_loss: 2.7734 - val_accuracy: 0.7143
# Epoch 228/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.1728 - accuracy: 0.9529 - val_loss: 2.8256 - val_accuracy: 0.7119
# Epoch 229/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1730 - accuracy: 0.9529 - val_loss: 2.7708 - val_accuracy: 0.7310
# Epoch 230/1000
# 17/17 [==============================] - 0s 22ms/step - loss: 0.1757 - accuracy: 0.9519 - val_loss: 2.7812 - val_accuracy: 0.7190
# Epoch 231/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1626 - accuracy: 0.9563 - val_loss: 2.8296 - val_accuracy: 0.7167
# Epoch 232/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.1640 - accuracy: 0.9548 - val_loss: 2.8308 - val_accuracy: 0.7167
# Epoch 233/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.1657 - accuracy: 0.9542 - val_loss: 2.8718 - val_accuracy: 0.6952
# Epoch 234/1000
# 17/17 [==============================] - 0s 28ms/step - loss: 0.1623 - accuracy: 0.9529 - val_loss: 2.9199 - val_accuracy: 0.6929
# Epoch 235/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.1628 - accuracy: 0.9511 - val_loss: 2.8268 - val_accuracy: 0.7024
# Epoch 236/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.1639 - accuracy: 0.9524 - val_loss: 2.8254 - val_accuracy: 0.7071
# Epoch 237/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1564 - accuracy: 0.9595 - val_loss: 2.8451 - val_accuracy: 0.7000
# Epoch 238/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1576 - accuracy: 0.9556 - val_loss: 2.8782 - val_accuracy: 0.7071
# Epoch 239/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.1587 - accuracy: 0.9532 - val_loss: 2.8185 - val_accuracy: 0.7238
# Epoch 240/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.1531 - accuracy: 0.9579 - val_loss: 2.8329 - val_accuracy: 0.7095
# Epoch 241/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.1555 - accuracy: 0.9553 - val_loss: 2.7906 - val_accuracy: 0.7190
# Epoch 242/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.1564 - accuracy: 0.9542 - val_loss: 2.8592 - val_accuracy: 0.7048
# Epoch 243/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1514 - accuracy: 0.9548 - val_loss: 2.9628 - val_accuracy: 0.6976
# Epoch 244/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1491 - accuracy: 0.9574 - val_loss: 2.8490 - val_accuracy: 0.7143
# Epoch 245/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.1543 - accuracy: 0.9566 - val_loss: 2.9174 - val_accuracy: 0.7095
# Epoch 246/1000
# 17/17 [==============================] - 0s 22ms/step - loss: 0.1511 - accuracy: 0.9563 - val_loss: 2.8258 - val_accuracy: 0.7262
# Epoch 247/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1468 - accuracy: 0.9582 - val_loss: 2.9195 - val_accuracy: 0.7071
# Epoch 248/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.1476 - accuracy: 0.9574 - val_loss: 2.8849 - val_accuracy: 0.7071
# Epoch 249/1000
# 17/17 [==============================] - 1s 32ms/step - loss: 0.1491 - accuracy: 0.9582 - val_loss: 2.7968 - val_accuracy: 0.7286
# Epoch 250/1000
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1413 - accuracy: 0.9608 - val_loss: 2.9406 - val_accuracy: 0.6833
# Epoch 251/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1470 - accuracy: 0.9587 - val_loss: 2.8615 - val_accuracy: 0.7190
# Epoch 252/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1472 - accuracy: 0.9595 - val_loss: 2.9097 - val_accuracy: 0.6952
# Epoch 253/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1496 - accuracy: 0.9614 - val_loss: 2.8001 - val_accuracy: 0.7214
# Epoch 254/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1417 - accuracy: 0.9619 - val_loss: 2.8756 - val_accuracy: 0.7143
# Epoch 255/1000
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1379 - accuracy: 0.9627 - val_loss: 2.8675 - val_accuracy: 0.7000
# Epoch 256/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1431 - accuracy: 0.9616 - val_loss: 2.8447 - val_accuracy: 0.7095
# Epoch 257/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1376 - accuracy: 0.9614 - val_loss: 2.8025 - val_accuracy: 0.7238
# Epoch 258/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1340 - accuracy: 0.9616 - val_loss: 2.8745 - val_accuracy: 0.7095
# Epoch 259/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1429 - accuracy: 0.9587 - val_loss: 2.8607 - val_accuracy: 0.7119
# Epoch 260/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.1360 - accuracy: 0.9601 - val_loss: 2.8775 - val_accuracy: 0.7071
# Epoch 261/1000
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1363 - accuracy: 0.9590 - val_loss: 2.8904 - val_accuracy: 0.6929
# Epoch 262/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.1295 - accuracy: 0.9635 - val_loss: 2.8515 - val_accuracy: 0.7071
# Epoch 263/1000
# 17/17 [==============================] - 1s 27ms/step - loss: 0.1366 - accuracy: 0.9624 - val_loss: 2.8499 - val_accuracy: 0.7214
# Epoch 264/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.1331 - accuracy: 0.9614 - val_loss: 2.9114 - val_accuracy: 0.6929
# Epoch 265/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1399 - accuracy: 0.9593 - val_loss: 2.8494 - val_accuracy: 0.7167
# Epoch 266/1000
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1334 - accuracy: 0.9635 - val_loss: 2.9592 - val_accuracy: 0.6929
# Epoch 267/1000
# 17/17 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9632Restoring model weights from the end of the best epoch: 262.
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1317 - accuracy: 0.9632 - val_loss: 2.9334 - val_accuracy: 0.6929
# Epoch 267: early stopping

# %%
model.save('seq2seq-attention-variable')
# Out:
# INFO:tensorflow:Assets written to: seq2seq-attention-variable/assets

# %%
# Babysit the model
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

pd.DataFrame({'val_loss':history.history['val_loss'],
              'loss':history.history['loss'],
             }).plot(ax=ax1)
pd.DataFrame({'val_accuracy':history.history['val_accuracy'],
              'accuracy':history.history['accuracy']
             }).plot(ax=ax2)

min(history.history['loss']), max(history.history['accuracy'])
# Out:
# (0.12945516407489777, 0.9634920358657837)

# %%
attention_func
# Out:
# 'MLP'

# %% [markdown]
# * no attention : (0.170416459441185, 0.9534391760826111)
# * dot : (0.19616758823394775, 0.9447090029716492)
# * bilinear : (0.266628623008728, 0.9269841313362122)
# * MLP : (0.12090284377336502, 0.9666666388511658)

# %% [markdown]
# ## Inference

# %%
# Pour décoder, il faut transformer un entier en mot.
token2word = {token:word for token, word in enumerate(english_vectorizer.get_vocabulary())}
word2token = {v:k for k, v in token2word.items()}

def decode_english_sentence(lang):
    return " ".join([token2word[t] for t in lang]).strip()

# %%
i2w = {token:word for token, word in enumerate(spanish_vectorizer.get_vocabulary())}
#wi = {v:k for k, v in i2w.items()}

# %%
def translate(spanish_sent, preprocessing=False):
    # Encode the input as state vectors.
    if not preprocessing:
        spanish_sent = step1(spanish_sent)
    
    # Sampling loop for decoding one sentence.
    stop_condition = False
    steps = 0
    
    # Build teacher for first step i.e. populate the first word of target sequence with "<start>".
    target_seq = np.zeros(((1, max_length_english)))
    target_seq[0, steps] = word2token["<start>"]
    
    while not stop_condition:        
        # Predict
        predicted_tokens = model.predict([np.array(spanish_sent, ndmin=2), target_seq], verbose=0)
        predicted_tokens = np.argmax(predicted_tokens, axis=2)
        
        # Sample a token
        sampled_token_index = predicted_tokens[0, steps]
        
        # Update the target sequence.
        steps += 1
        target_seq[0, steps] = sampled_token_index
        
        # Exit condition: either hit max length
        # or find stop character.
        if sampled_token_index==word2token['<end>'] or steps==max_length_english-1:
            stop_condition = True
    return decode_english_sentence(target_seq[0])

# %%
# Permet de rechercher les phrases correctes.
from tqdm import tqdm

correct = []
incorrect = []
for i, (spanish_sent, english_sent) in tqdm(enumerate(zip(spanish_sentences, english_sentences))):
    decoded_sentence = translate(spanish_sent)
    decoded = english_vectorizer(decoded_sentence).numpy()
    original = english_vectorizer(english_sent).numpy()
    if len(decoded)==len(original) and sum(decoded==original)==len(original):
        correct += [i]
    else:
        incorrect += [i]
# Out:
# 600it [03:55,  2.55it/s]

# %%
len(correct), len(correct)/len(spanish_sentences)*100
# Out:
# (219, 36.5)

# %% [markdown]
# On train set:
# * with variable length (208, 34.66)
# * with MLP attention and variable length (218, 36.333333333333336)

# %%
# Décode les phrases correctes sélectionnées
for spanish_sent, english_sent in zip(spanish_sentences[correct[-10:]], english_sentences[correct[-10:]]):
    print("="*50)
    print(spanish_sent, "-->", english_sent)
    decoded_sentence = translate(spanish_sent)
    print(english_sent, "???", decoded_sentence)
# Out:
# ==================================================
# <start> te lo ruego . <end> --> <start> i beg you . <end>
# <start> i beg you . <end> ??? <start> i beg you . <end>
# ==================================================
# <start> te lo suplico . <end> --> <start> i beg you . <end>
# <start> i beg you . <end> ??? <start> i beg you . <end>
# ==================================================
# <start> puedo volar . <end> --> <start> i can fly . <end>
# <start> i can fly . <end> ??? <start> i can fly . <end>
# ==================================================
# <start> perdi la consciencia . <end> --> <start> i fainted . <end>
# <start> i fainted . <end> ??? <start> i fainted . <end>
# ==================================================
# <start> quede inconsciente . <end> --> <start> i fainted . <end>
# <start> i fainted . <end> ??? <start> i fainted . <end>
# ==================================================
# <start> me rendi . <end> --> <start> i gave up . <end>
# <start> i gave up . <end> ??? <start> i gave up . <end>
# ==================================================
# <start> tire la toalla . <end> --> <start> i gave up . <end>
# <start> i gave up . <end> ??? <start> i gave up . <end>
# ==================================================
# <start> te entiendo . <end> --> <start> i get you . <end>
# <start> i get you . <end> ??? <start> i get you . <end>
# ==================================================
# <start> te pillo . <end> --> <start> i get you . <end>
# <start> i get you . <end> ??? <start> i get you . <end>
# ==================================================
# <start> ya te pillo . <end> --> <start> i get you . <end>
# <start> i get you . <end> ??? <start> i get you . <end>

# %%
# Décode les phrases incorrectes sélectionnées
for spanish_sent, english_sent in zip(spanish_sentences[incorrect[-10:]], english_sentences[incorrect[-10:]]):
    print("="*50)
    print(spanish_sent, "-->", english_sent)
    decoded_sentence = translate(spanish_sent)
    print(english_sent, "???", decoded_sentence)
# Out:
# ==================================================
# <start> estoy quebrado . <end> --> <start> i m broke . <end>
# <start> i m broke . <end> ??? <start> it s me . <end>
# ==================================================
# <start> estoy sin blanca . <end> --> <start> i m broke . <end>
# <start> i m broke . <end> ??? <start> it s me . <end>
# ==================================================
# <start> no tengo blanca . <end> --> <start> i m broke . <end>
# <start> i m broke . <end> ??? <start> don t go . <end>
# ==================================================
# <start> estoy loco . <end> --> <start> i m crazy . <end>
# <start> i m crazy . <end> ??? <start> it s me . <end>
# ==================================================
# <start> estoy borracho . <end> --> <start> i m drunk . <end>
# <start> i m drunk . <end> ??? <start> it s me . <end>
# ==================================================
# <start> estoy tomada . <end> --> <start> i m drunk . <end>
# <start> i m drunk . <end> ??? <start> it s me . <end>
# ==================================================
# <start> estoy prendida . <end> --> <start> i m drunk . <end>
# <start> i m drunk . <end> ??? <start> it s me . <end>
# ==================================================
# <start> me estoy muriendo . <end> --> <start> i m dying . <end>
# <start> i m dying . <end> ??? <start> i m . <end>
# ==================================================
# <start> soy el primero . <end> --> <start> i m first . <end>
# <start> i m first . <end> ??? <start> it s me . <end>
# ==================================================
# <start> voy el primero . <end> --> <start> i m first . <end>
# <start> i m first . <end> ??? <start> humor me . <end>

# %% [markdown]
# ##  Performance on never before seen data
#
# <font color='red'>
#     <bold>Warning:</bold> remember that we have overfitted the model and that we are only working on train data... and not test data.
# </font>

# %%
# Permet de rechercher les phrases correctes.
from tqdm import tqdm

test_correct = []
for i, (spanish_sent, english_sent) in tqdm(enumerate(zip(test_spanish_sentences, test_english_sentences))):
    decoded_sentence = translate(spanish_sent)
    decoded = english_vectorizer(decoded_sentence).numpy()
    original = english_vectorizer(english_sent).numpy()
    if len(decoded)==len(original) and sum(decoded==original)==len(original):
        test_correct += [i]
len(test_correct), len(test_correct)/len(test_spanish_sentences)*100
# Out:
# 100it [00:42,  2.36it/s]
# (0, 0.0)

# %% [markdown]
# ## Plotting attention matrix

# %%
""" The activation matrix is extracted from the previous model. """
attention_model = Model([encoder_inputs, decoder_inputs], attention)
plot_model(attention_model, show_shapes=True)

# %%
""" Apply model on one sentence """
id = 74 # 13, 42, 74

# %%
import seaborn as sns

attention_matrix = attention_model.predict([spanish_sentences[id:id+1], english_teacher_enc[id:id+1]])[0]

x_labels = [spanish_vectorizer.get_vocabulary()[i] for i in spanish_vectorizer(spanish_sentences[id]).numpy() if i!=0]
y_labels = [english_vectorizer.get_vocabulary()[i] for i in english_teacher_enc[id][:] if i!=0]
attention_matrix = attention_matrix[:len(y_labels),:len(x_labels)]
print(np.sum(attention_matrix, axis=1))


#x_labels.reverse()
#y_labels.reverse()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(3, 3))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(255, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(attention_matrix, vmax=1.0,
            xticklabels=x_labels,
            yticklabels=y_labels,
            cmap=cmap,
            center=0,
            square=True,
            linewidths=.5,
            cbar_kws={"shrink": .7},
           );
# Out:
# 1/1 [==============================] - 0s 13ms/step
# [1. 1. 1. 1. 1.]

# %% [markdown]
# Poids respectifs entre c et h pour prédire lors de la dernière couche.

# %%
last_layer = model.layers[-1]
weights = last_layer.get_weights()

context_weigths = np.sum(weights[0][:64,:], axis=0)
hidden_weigths = np.sum(weights[0][64:,:], axis=0)

m = np.zeros((len(y_labels), 2))
for i, j in enumerate(english_teacher_enc[id][:len(y_labels)]):
    # Context from attention // Decoder output
    c = abs(context_weigths[j])
    h = abs(hidden_weigths[j])
    #print(context_weigths[j], hidden_weigths[j])
    m[i,:] = [c/(c+h),h/(h+c)]

sns.heatmap(m, vmax=1.0,
            xticklabels=["attention", "decoder"],
            yticklabels=y_labels,
            cmap=cmap,
            center=0,
            square=True,
            linewidths=.5,
            cbar_kws={"shrink": .7},
           );

# %%
for i in english_teacher_enc[id]:
    # Context from attention // Decoder output
    c = abs(context_weigths[i])
    h = abs(hidden_weigths[i])
    #print(context_weigths[i], hidden_weigths[i])
    print(int(100*c/(c+h)), int(100*h/(h+c)))
# Out:
# 62 37
# 87 12
# 54 45
# 41 58
# 17 82
# 66 33
# 66 33

# %%
#Understand the network
#Build Attentional network
